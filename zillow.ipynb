# %%
import pandas as pd
import numpy as np
import os

import wrangle as w
from env import hostname, user, password
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler,QuantileTransformer
import warnings
warnings.filterwarnings("ignore")

# %%
# def get_zillow_data():
#    # acquire required tables into one dataframe
#     file='zillow_df.csv'
#     if os.path.isfile(filename):
#         return pd.read_csv(filename)
#     else:
#         sql_quert = p'''SELECT
#             prop.*,
#             predictions_2017.logerror,
#             predictions_2017.transactiondate,
#             air.airconditioningdesc,
#             arch.architecturalstyledesc,
#             build.buildingclassdesc,
#             heat.heatingorsystemdesc,
#             landuse.propertylandusedesc,
#             story.storydesc,
#             construct.typeconstructiondesc
#         FROM properties_2017 prop
#         JOIN (
#             SELECT parcelid, MAX(transactiondate) max_transactiondate
#             FROM predictions_2017
#             GROUP BY parcelid
#         ) pred USING(parcelid)
#         JOIN predictions_2017 ON pred.parcelid = predictions_2017.parcelid
#                               AND pred.max_transactiondate = predictions_2017.transactiondate
#         LEFT JOIN airconditioningtype air USING (airconditioningtypeid)
#         LEFT JOIN architecturalstyletype arch USING (architecturalstyletypeid)
#         LEFT JOIN buildingclasstype build USING (buildingclasstypeid)
#         LEFT JOIN heatingorsystemtype heat USING (heatingorsystemtypeid)
#         LEFT JOIN propertylandusetype landuse USING (propertylandusetypeid)
#         LEFT JOIN storytype story USING (storytypeid)
#         LEFT JOIN typeconstructiontype construct USING (typeconstructiontypeid)
#         WHERE prop.latitude IS NOT NULL
#           AND prop.longitude IS NOT NULL
#           AND predictions_2017.transactiondate like "2017%%" ''')
#         df = pd.read_sql(sql_query, get_connection('zillow'))
#         df.to_csv(filename, index=False)
#         return df
import os
import pandas as pd

def get_zillow_data():
    # Define the filename
    filename = 'zillow_df.csv'
    
    # Check if the file exists
    if os.path.isfile(filename):
        return pd.read_csv(filename)
    else:
        # SQL query to retrieve the required data
        sql_query = '''
        SELECT
            prop.*,
            predictions_2017.logerror,
            predictions_2017.transactiondate,
            air.airconditioningdesc,
            arch.architecturalstyledesc,
            build.buildingclassdesc,
            heat.heatingorsystemdesc,
            landuse.propertylandusedesc,
            story.storydesc,
            construct.typeconstructiondesc
        FROM properties_2017 prop
        JOIN (
            SELECT parcelid, MAX(transactiondate) max_transactiondate
            FROM predictions_2017
            GROUP BY parcelid
        ) pred USING(parcelid)
        JOIN predictions_2017 ON pred.parcelid = predictions_2017.parcelid
                              AND pred.max_transactiondate = predictions_2017.transactiondate
        LEFT JOIN airconditioningtype air USING (airconditioningtypeid)
        LEFT JOIN architecturalstyletype arch USING (architecturalstyletypeid)
        LEFT JOIN buildingclasstype build USING (buildingclasstypeid)
        LEFT JOIN heatingorsystemtype heat USING (heatingorsystemtypeid)
        LEFT JOIN propertylandusetype landuse USING (propertylandusetypeid)
        LEFT JOIN storytype story USING (storytypeid)
        LEFT JOIN typeconstructiontype construct USING (typeconstructiontypeid)
        WHERE prop.latitude IS NOT NULL
          AND prop.longitude IS NOT NULL
          AND predictions_2017.transactiondate LIKE '2017%%'
        '''
        # Retrieve data from the database and save it as a CSV file
        df = pd.read_sql(sql_query, get_connection('zillow'))
        df.to_csv(filename, index=False)
        return df

# %%
df = w.get_zillow_data()
df.head()
# Out:
#         id  parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 0  1727539  14297519                    NaN                       NaN
# 1  1387261  17052889                    NaN                       NaN
# 2    11677  14186244                    NaN                       NaN
# 3  2288172  12177905                    NaN                       NaN
# 4  1970746  10887214                    1.0                       NaN
#
#    basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 0           NaN          3.5         4.0                  NaN
# 1           NaN          1.0         2.0                  NaN
# 2           NaN          2.0         3.0                  NaN
# 3           NaN          3.0         4.0                  NaN
# 4           NaN          3.0         3.0                  NaN
#
#    buildingqualitytypeid  calculatedbathnbr  ...  censustractandblock  \
# 0                    NaN                3.5  ...         6.059063e+13
# ...

# %%
df.describe()
# Out:
#                  id      parcelid  airconditioningtypeid  \
# count  7.738000e+04  7.738000e+04           24953.000000
# mean   1.495126e+06  1.300715e+07               1.813289
# std    8.609057e+05  3.481368e+06               2.967894
# min    3.490000e+02  1.071186e+07               1.000000
# 25%    7.520500e+05  1.153830e+07               1.000000
# 50%    1.497870e+06  1.253155e+07               1.000000
# 75%    2.240480e+06  1.421184e+07               1.000000
# max    2.982274e+06  1.676893e+08              13.000000
#
#        architecturalstyletypeid  basementsqft   bathroomcnt    bedroomcnt  \
# count                206.000000     50.000000  77380.000000  77380.000000
# mean                   7.388350    679.720000      2.299134      3.053489
# std                    2.734542    689.703546      0.996657      1.139103
# min                    2.000000     38.000000      0.000000      0.000000
# 25%                    7.000000    273.000000      2.000000      2.000000
# ...

# %%
df.isnull().sum()
# Out:
# id                              0
# parcelid                        0
# airconditioningtypeid       52427
# architecturalstyletypeid    77174
# basementsqft                77330
#                             ...
# buildingclassdesc           77365
# heatingorsystemdesc         27941
# propertylandusedesc             0
# storydesc                   77330
# typeconstructiondesc        77158
# Length: 68, dtype: int64

# %%
df.shape
# Out:
# (77380, 68)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77380 entries, 0 to 77379
# Data columns (total 68 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            77380 non-null  int64
#  1   parcelid                      77380 non-null  int64
#  2   airconditioningtypeid         24953 non-null  float64
#  3   architecturalstyletypeid      206 non-null    float64
#  4   basementsqft                  50 non-null     float64
#  5   bathroomcnt                   77380 non-null  float64
#  6   bedroomcnt                    77380 non-null  float64
#  7   buildingclasstypeid           15 non-null     float64
#  8   buildingqualitytypeid         49671 non-null  float64
#  9   calculatedbathnbr             76771 non-null  float64
#  10  decktypeid                    614 non-null    float64
#  11  finishedfloor1squarefeet      6023 non-null   float64
# ...

# %%
# Filter properties with a transaction in 2017
df_2017 = df[df['transactiondate'].str.startswith('2017')]
df.head()
# Out:
#         id  parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 0  1727539  14297519                    NaN                       NaN
# 1  1387261  17052889                    NaN                       NaN
# 2    11677  14186244                    NaN                       NaN
# 3  2288172  12177905                    NaN                       NaN
# 4  1970746  10887214                    1.0                       NaN
#
#    basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 0           NaN          3.5         4.0                  NaN
# 1           NaN          1.0         2.0                  NaN
# 2           NaN          2.0         3.0                  NaN
# 3           NaN          3.0         4.0                  NaN
# 4           NaN          3.0         3.0                  NaN
#
#    buildingqualitytypeid  calculatedbathnbr  ...  censustractandblock  \
# 0                    NaN                3.5  ...         6.059063e+13
# ...

# %% [markdown]
# Write a function that takes in a dataframe of observations and attributes and returns a dataframe where each row is an atttribute name, the first column is the number of rows with missing values for that attribute, and the second column is percent of total rows that have missing values for that attribute. Run the function and document takeaways from this on how you want to handle missing values.

# %%
#John G code
def missing_nulls(df):
    num_missing = df.isnull().sum()
    rows = df.shape[0]
    pct_missing = num_missing / rows
    cols_missing = pd.DataFrame({'number_missing_rows': num_missing, 'percent_rows_missing': pct_missing})
    return cols_missing

# %%
missing_nulls(df)
# Out:
#                           number_missing_rows  percent_rows_missing
# id                                          0              0.000000
# parcelid                                    0              0.000000
# airconditioningtypeid                   52427              0.677526
# architecturalstyletypeid                77174              0.997338
# basementsqft                            77330              0.999354
# ...                                       ...                   ...
# buildingclassdesc                       77365              0.999806
# heatingorsystemdesc                     27941              0.361088
# propertylandusedesc                         0              0.000000
# storydesc                               77330              0.999354
# typeconstructiondesc                    77158              0.997131
#
# [68 rows x 2 columns]

# %%
df.nulls_by_column.sort_values(by="percent_rows_missing", ascending=False).head(40)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df.nulls_by_column.sort_values(by="percent_rows_missing", ascending=False).head(40)
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'nulls_by_column'

# %% [markdown]
# 2. Remove any properties that are likely to be something other than single unit properties. (e.g. no duplexes, no land/lot, ...). There are multiple ways to estimate that a property is a single unit, and there is not a single "right" answer. But for this exercise, do not purely filter by unitcnt as we did previously. Add some new logic that will reduce the number of properties that are falsely removed. You might want to use # bedrooms, square feet, unit type or the like to then identify those with unitcnt not defined.

# %%
# calue counts by unit 

df.unitcnt.value_counts(dropna = False)
# Out:
# 1.0      47292
# NaN      26818
# 2.0       2018
# 4.0        723
# 3.0        525
# 45.0         1
# 42.0         1
# 6.0          1
# 237.0        1
# Name: unitcnt, dtype: int64

# %%
# Remove unnecessary propertie, leaveonly properties that meet SU criteria

single_use = [261, 262, 263, 264, 266, 268, 273, 276, 279]
df = df[df.propertylandusetypeid.isin(single_use)]
    
    
# Restrict df to only those properties with at least 1 bath & bed and >350 sqft area
df = df[(df.bedroomcnt > 0) & (df.bathroomcnt > 0) & ((df.unitcnt<=1)|df.unitcnt.isnull()) & (df.calculatedfinishedsqft)
# Out:
#   Cell In[49], line 8
#     df = df[(df.bedroomcnt > 0) & (df.bathroomcnt > 0) & ((df.unitcnt<=1)|df.unitcnt.isnull()) & (df.calculatedfinishedsqft)
#                                                                                                                             ^
# SyntaxError: incomplete input

# %% [markdown]
# Create a function that will drop rows or columns based on the percent of values that are missing: handle_missing_values(df, prop_required_column, prop_required_row).

# %%
def clean_missing_values(df, prop_required_column = .5, prop_required_row = .70):
    threshold = int(round(prop_required_column*len(df.index),0))
    df.dropna(axis=1, thresh=threshold, inplace=True)
    threshold = int(round(prop_required_row*len(df.columns),0))
    df.dropna(axis=0, thresh=threshold, inplace=True)
    return df

# %%
clean_missing_values(df)
# Out:
#             id  parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 0      1727539  14297519          3.5         4.0                    NaN
# 1      1387261  17052889          1.0         2.0                    NaN
# 2        11677  14186244          2.0         3.0                    NaN
# 3      2288172  12177905          3.0         4.0                    8.0
# 4      1970746  10887214          3.0         3.0                    8.0
# ...        ...       ...          ...         ...                    ...
# 77375  2864704  10833991          3.0         3.0                    8.0
# 77376   673515  11000655          2.0         2.0                    6.0
# 77377  2968375  17239384          2.0         4.0                    NaN
# 77378  1843709  12773139          1.0         3.0                    4.0
# 77379  1187175  12826780          2.0         3.0                    6.0
#
#        calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# ...

# %%
df.shape
# Out:
# (77304, 34)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77304 entries, 0 to 77379
# Data columns (total 34 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            77304 non-null  int64
#  1   parcelid                      77304 non-null  int64
#  2   bathroomcnt                   77304 non-null  float64
#  3   bedroomcnt                    77304 non-null  float64
#  4   buildingqualitytypeid         49671 non-null  float64
#  5   calculatedbathnbr             76771 non-null  float64
#  6   calculatedfinishedsquarefeet  77184 non-null  float64
#  7   finishedsquarefeet12          73748 non-null  float64
#  8   fips                          77304 non-null  float64
#  9   fullbathcnt                   76771 non-null  float64
#  10  heatingorsystemtypeid         49439 non-null  float64
#  11  latitude                      77304 non-null  float64
# ...

# %%
cols_to_remove = ['id',
       'calculatedbathnbr', 'finishedsquarefeet12', 'fullbathcnt', 'heatingorsystemtypeid'
       ,'propertycountylandusecode', 'propertylandusetypeid','propertyzoningdesc', 
        'censustractandblock', 'propertylandusedesc', 'unitcnt']

# %%
#drop null values 
df.dropna()
# Out:
#             id  parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 3      2288172  12177905          3.0         4.0                    8.0
# 4      1970746  10887214          3.0         3.0                    8.0
# 6       781532  12095076          3.0         4.0                    9.0
# 8      1246926  12790562          3.0         4.0                    9.0
# 9      1585097  11542646          3.0         2.0                    8.0
# ...        ...       ...          ...         ...                    ...
# 77374  2274245  12412492          2.0         4.0                    6.0
# 77375  2864704  10833991          3.0         3.0                    8.0
# 77376   673515  11000655          2.0         2.0                    6.0
# 77378  1843709  12773139          1.0         3.0                    4.0
# 77379  1187175  12826780          2.0         3.0                    6.0
#
#        calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# ...

# %%
df.isnull().sum()
# Out:
# id                                  0
# parcelid                            0
# bathroomcnt                         0
# bedroomcnt                          0
# buildingqualitytypeid           27633
# calculatedbathnbr                 533
# calculatedfinishedsquarefeet      120
# finishedsquarefeet12             3556
# fips                                0
# fullbathcnt                       533
# heatingorsystemtypeid           27865
# latitude                            0
# longitude                           0
# lotsizesquarefeet                8171
# propertycountylandusecode           0
# propertylandusetypeid               0
# propertyzoningdesc              26987
# rawcensustractandblock              0
# regionidcity                     1460
# regionidcounty                      0
# regionidzip                        45
# roomcnt                             0
# unitcnt                         26742
# yearbuilt                         187
# structuretaxvaluedollarcnt        102
# ...

# %%
# Sort the DataFrame by transactiondate in descending order
df_2017.sort_values('transactiondate', ascending=False, inplace=True)
df_2017.head()
# Out:
#             id  parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 77379  1187175  12826780                    NaN                       NaN
# 77377  2968375  17239384                    NaN                       NaN
# 77378  1843709  12773139                    1.0                       NaN
# 77376   673515  11000655                    NaN                       NaN
# 77375  2864704  10833991                    1.0                       NaN
#
#        basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 77379           NaN          2.0         3.0                  NaN
# 77377           NaN          2.0         4.0                  NaN
# 77378           NaN          1.0         3.0                  NaN
# 77376           NaN          2.0         2.0                  NaN
# 77375           NaN          3.0         3.0                  NaN
#
#        buildingqualitytypeid  calculatedbathnbr  ...  censustractandblock  \
# ...

# %%
# Keep only the last transaction for each property ID
df_2017.drop_duplicates(subset='propertyid', inplace=True)
df_2017.datatype(
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Keep only the last transaction for each property ID
# ----> 2 df_2017.drop_duplicates(subset='propertyid', inplace=True)
#       3 df_2017.head()
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:6672, in DataFrame.drop_duplicates(self, subset, keep, inplace, ignore_index)
# ...

# %%
# Filter properties with latitude and longitude values
df_filtered = df_2017[df_2017['latitude'].notnull() & df_2017['longitude'].notnull()]

# Select required columns (propertyid, logerror, transactiondate)
df_final = df_filtered[['propertyid', 'logerror', 'transactiondate']]

# Reset the index of the final DataFrame
df_final.reset_index(drop=True, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 8
#       5 df_2017.sort_values('transactiondate', ascending=False, inplace=True)
#       7 # Keep only the last transaction for each property ID
# ----> 8 df_2017.drop_duplicates(subset='propertyid', inplace=True)
#      10 # Filter properties with latitude and longitude values
#      11 df_filtered = df_2017[df_2017['latitude'].notnull() & df_2017['longitude'].notnull()]
#
# File /opt/homebrew/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
df.head()
# Out:
#         id  parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 0  1727539  14297519                    NaN                       NaN
# 1  1387261  17052889                    NaN                       NaN
# 2    11677  14186244                    NaN                       NaN
# 3  2288172  12177905                    NaN                       NaN
# 4  1970746  10887214                    1.0                       NaN
#
#    basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 0           NaN          3.5         4.0                  NaN
# 1           NaN          1.0         2.0                  NaN
# 2           NaN          2.0         3.0                  NaN
# 3           NaN          3.0         4.0                  NaN
# 4           NaN          3.0         3.0                  NaN
#
#    buildingqualitytypeid  calculatedbathnbr  ...  censustractandblock  \
# 0                    NaN                3.5  ...         6.059063e+13
# ...
